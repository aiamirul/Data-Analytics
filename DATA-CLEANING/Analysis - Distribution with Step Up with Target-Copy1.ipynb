# %% [markdown]
# # Load CSV data

# %% [markdown]
# loan_data_test.csv

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import numpy as np
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
WorkSpaceName = 'StepUpWithTarget'
data = pd.read_csv("Distribution with Step Up with Target.csv") 
# Preview the first 5 lines of the loaded data 
print(data.shape)
print(data.columns)
data.head(100)
# Out:
# (992081, 46)
# Index(['Bil.no', 'ID', 'I', 'D', 'FacilityType', 'FI', 'FAC No.',
#        'CollateralValue', 'RestructureLoan', 'PaymentVia', 'Tenure',
#        'CurrentInstallment', 'Interest', 'PrincipleAmount',
#        'PtgWaiverPrinciple', 'WaiverOnPrinciple', 'PrincipleAfterWaiver',
#        'IIS', 'ProposedInterestRate', 'WaiverOnIIS', 'IISAfterWaiver',
#        'PenaltyInterest', 'PtgWaiverPenaltyInterest',
#        'WaiverOnPenaltyIntAmount', 'PenaltyIntAfterWaiver', 'OtherChargers',
#        'PtgWaiverOtherCharges', 'WaiverOnOthCharges', 'OtherChrgesAfterWaiver',
#        'TotalOSBeforeWaiver', 'TotalOSAfterWaiver', 'Target',
#        'TenureAfterWaiver', 'CrdtStatus', 'InstlmentAfterWaiver',
#        'ProposedInstallment', 'StepUp', 'StepUpAMount', 'RepaymentAmount',
#        'StepUpStartDate', 'StepUpEndDate', 'matrix', 'Column1', 'Column2',
#        'Column3', 'Column4'],
#       dtype='object')
#     Bil.no   ID  I   D  FacilityType    FI FAC No.  CollateralValue  \
# 0        1   H2  H   2  Credit Cards  FI10    FAC1              0.0
# 1        2   H2  H   2  Credit Cards  FI10    FAC2              0.0
# 2        3   H2  H   2  Credit Cards  FI27    FAC3              0.0
# 3        4   H2  H   2  Credit Cards  FI27    FAC4              0.0
# 4        5   H2  H   2  Credit Cards  FI33    FAC5              0.0
# ..     ...  ... ..  ..           ...   ...     ...              ...
# 95      96  H58  H  58  Credit Cards   FI1   FAC96              0.0
# 96      97  H58  H  58  Credit Cards  FI25   FAC97              0.0
# 97      98  H58  H  58  Credit Cards  FI28   FAC98              0.0
# 98      99  H58  H  58  Credit Cards  FI51   FAC99              0.0
# 99     100  H59  H  59  Credit Cards  FI51  FAC100              0.0
#
#    RestructureLoan PaymentVia  ...  StepUp  StepUpAMount  RepaymentAmount  \
# 0              Yes       AKPK  ...     NaN           NaN              NaN
# 1              Yes       AKPK  ...     NaN           NaN              NaN
# 2              Yes       AKPK  ...     NaN           NaN              NaN
# 3              Yes       AKPK  ...     NaN           NaN              NaN
# 4              Yes       AKPK  ...     NaN           NaN              NaN
# ..             ...        ...  ...     ...           ...              ...
# 95             Yes       AKPK  ...     1.0           0.0             90.0
# 96             Yes       AKPK  ...     1.0           0.0            430.0
# 97             Yes       AKPK  ...     1.0           0.0             70.0
# 98             Yes       AKPK  ...     1.0           0.0            310.0
# 99             Yes       AKPK  ...     NaN           NaN              NaN
#
#     StepUpStartDate  StepUpEndDate    matrix  Column1  Column2  Column3  \
# 0               NaN            NaN  Matrix 1      0.0      NaN      NaN
# 1               NaN            NaN  Matrix 1      0.0      NaN      NaN
# 2               NaN            NaN  Matrix 1      0.0      NaN      NaN
# 3               NaN            NaN  Matrix 1      0.0      NaN      NaN
# 4               NaN            NaN  Matrix 1      0.0      NaN      NaN
# ..              ...            ...       ...      ...      ...      ...
# 95       2012-09-01     2022-08-31  Matrix 1     90.0      NaN      NaN
# 96       2012-09-01     2022-08-31  Matrix 1    430.0      NaN      NaN
# 97       2012-09-01     2022-08-31  Matrix 1     70.0      NaN      NaN
# 98       2012-09-01     2022-08-31  Matrix 1    310.0      NaN      NaN
# 99              NaN            NaN  Matrix 1     50.0      NaN      NaN
#
#     Column4
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 95      NaN
# 96      NaN
# 97      NaN
# 98      NaN
# 99      NaN
#
# [100 rows x 46 columns]

# %%
#droppng of irrelevant columns and rows with missing values
columns_to_drop = ['Bil.no','StepUpStartDate','StepUpEndDate','ID','FacilityType','FAC No.','FI','Column1',]
data.drop(columns=columns_to_drop, inplace=True, axis=1)

# %%
#dropping all missing values
data.dropna(inplace=True)
print(data.shape)
data.head()
# Out:
# (7497, 39)
#       I    D  CollateralValue RestructureLoan PaymentVia  Tenure  \
# 16    H   11              0.0             Yes       SELF   120.0
# 19    H   16              0.0             Yes       SELF     0.0
# 20    H   16              0.0             Yes       SELF     0.0
# 42    H   36              0.0             Yes       SELF   420.0
# 1098  H  425              0.0             Yes       SELF   120.0
#
#       CurrentInstallment  Interest  PrincipleAmount  PtgWaiverPrinciple  ...  \
# 16               1214.17      5.50         85703.73                 0.0  ...
# 19                  0.00      0.00         35401.00                 0.0  ...
# 20                  0.00      0.00         62643.00                 0.0  ...
# 42               4300.00      4.35        996053.92                 0.0  ...
# 1098              450.00      8.00         18000.00                 0.0  ...
#
#       InstlmentAfterWaiver  ProposedInstallment  StepUp  StepUpAMount  \
# 16                   720.0                720.0     1.0           0.0
# 19                   457.0                457.0     1.0           0.0
# 20                   400.0                400.0     1.0           0.0
# 42                  3650.0               3650.0     1.0           0.0
# 1098                 200.0                200.0     1.0           0.0
#
#       RepaymentAmount    matrix  Column1  Column2  Column3  Column4
# 16              720.0  Matrix 2    720.0    850.0   1110.0   1110.0
# 19              457.0  Matrix 2    457.0    457.0    457.0    457.0
# 20              400.0  Matrix 2    400.0    400.0    400.0    400.0
# 42             3650.0  Matrix 2   3650.0   4300.0   5150.0   5150.0
# 1098            200.0  Matrix 2    200.0    200.0    200.0    200.0
#
# [5 rows x 39 columns]

# %% [markdown]
# # View Imbalance Data

# %%
targetCol = 'Target'

print(data[targetCol].value_counts())
total = data[targetCol].count()

print('\nShow Classes and Percentage')
for f in  data[targetCol].unique():
    print(f, '\n', round(data[targetCol].value_counts()[f]/total,2), '%\n' )

#Bins = How many 
data[targetCol].value_counts().plot(kind='bar')
# Out:
# Minor Blacklist       517925
# Moderate Blacklist    225936
#  Level 1 Bankrupt     118931
# Priority Blacklist     91303
# Level 2 Bankrupt       30427
# Level 3 Bankrupt        7302
# Level 4 Bankrupt         257
# Name: Target, dtype: int64
#
# Show Classes and Percentage
# Priority Blacklist
#  0.09 %
#
# Minor Blacklist
#  0.52 %
#
# Moderate Blacklist
#  0.23 %
#
# Level 2 Bankrupt
#  0.03 %
#
#  Level 1 Bankrupt
#  0.12 %
#
# Level 3 Bankrupt
#  0.01 %
#
# Level 4 Bankrupt
#  0.0 %
# <AxesSubplot:>

# %% [markdown]
# # Change Target to Numeric

# %%
amountCategory = len(data[targetCol].unique())
listCategory = np.arange(start=0, stop=amountCategory, step=1)

FeatureImportance = pd.DataFrame({'Encoded':listCategory, 'Label':data[targetCol].unique()})
FeatureImportance
# Out:
#    Encoded               Label
# 0        0  Priority Blacklist
# 1        1     Minor Blacklist
# 2        2  Moderate Blacklist
# 3        3    Level 2 Bankrupt
# 4        4    Level 1 Bankrupt
# 5        5    Level 3 Bankrupt
# 6        6    Level 4 Bankrupt

# %%
data[targetCol].replace(data[targetCol].unique(),
                        listCategory, inplace=True)

# %% [markdown]
# # Draw Correlation Matrix

# %%
import pandas as pd
import numpy as np
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\t\anaconda3\lib\site-packages\pandas\io\formats\style.py:1264: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\t\anaconda3\lib\site-packages\pandas\io\formats\style.py:1265: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_a7553_row0_col0,#T_a7553_row1_col1,#T_a7553_row2_col2,#T_a7553_row3_col3,#T_a7553_row4_col4,#T_a7553_row5_col5,#T_a7553_row5_col8,#T_a7553_row6_col6,#T_a7553_row7_col7,#T_a7553_row8_col5,#T_a7553_row8_col8,#T_a7553_row9_col9,#T_a7553_row10_col10,#T_a7553_row11_col11,#T_a7553_row12_col12,#T_a7553_row13_col13,#T_a7553_row14_col14,#T_a7553_row15_col15,#T_a7553_row16_col16,#T_a7553_row17_col17,#T_a7553_row18_col18,#T_a7553_row19_col19,#T_a7553_row20_col20,#T_a7553_row21_col21,#T_a7553_row22_col22,#T_a7553_row23_col23,#T_a7553_row24_col24,#T_a7553_row25_col25,#T_a7553_row25_col26,#T_a7553_row26_col25,#T_a7553_row26_col26,#T_a7553_row28_col28,#T_a7553_row29_col29,#T_a7553_row30_col30,#T_a7553_row31_col31,#T_a7553_row32_col32{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col1,#T_a7553_row2_col28,#T_a7553_row9_col28,#T_a7553_row13_col28,#T_a7553_row15_col1,#T_a7553_row15_col28,#T_a7553_row17_col28,#T_a7553_row20_col28,#T_a7553_row21_col28,#T_a7553_row31_col3{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col2,#T_a7553_row22_col29{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_a7553_row0_col3,#T_a7553_row0_col4,#T_a7553_row1_col3,#T_a7553_row1_col4,#T_a7553_row2_col3,#T_a7553_row2_col4,#T_a7553_row2_col10,#T_a7553_row3_col4,#T_a7553_row4_col3,#T_a7553_row5_col3,#T_a7553_row5_col4,#T_a7553_row6_col3,#T_a7553_row6_col4,#T_a7553_row7_col3,#T_a7553_row7_col4,#T_a7553_row8_col3,#T_a7553_row8_col4,#T_a7553_row9_col3,#T_a7553_row9_col4,#T_a7553_row10_col0,#T_a7553_row10_col1,#T_a7553_row10_col2,#T_a7553_row10_col3,#T_a7553_row10_col4,#T_a7553_row10_col5,#T_a7553_row10_col6,#T_a7553_row10_col7,#T_a7553_row10_col8,#T_a7553_row10_col9,#T_a7553_row10_col11,#T_a7553_row10_col12,#T_a7553_row10_col13,#T_a7553_row10_col15,#T_a7553_row10_col16,#T_a7553_row10_col17,#T_a7553_row10_col18,#T_a7553_row10_col19,#T_a7553_row10_col20,#T_a7553_row10_col21,#T_a7553_row10_col22,#T_a7553_row10_col23,#T_a7553_row10_col24,#T_a7553_row10_col25,#T_a7553_row10_col26,#T_a7553_row10_col28,#T_a7553_row10_col29,#T_a7553_row10_col30,#T_a7553_row10_col31,#T_a7553_row11_col3,#T_a7553_row11_col4,#T_a7553_row12_col3,#T_a7553_row12_col4,#T_a7553_row13_col3,#T_a7553_row13_col4,#T_a7553_row14_col3,#T_a7553_row14_col4,#T_a7553_row14_col32,#T_a7553_row15_col3,#T_a7553_row15_col4,#T_a7553_row16_col3,#T_a7553_row16_col4,#T_a7553_row17_col3,#T_a7553_row17_col4,#T_a7553_row18_col3,#T_a7553_row18_col4,#T_a7553_row19_col3,#T_a7553_row19_col4,#T_a7553_row20_col3,#T_a7553_row20_col4,#T_a7553_row21_col3,#T_a7553_row21_col4,#T_a7553_row22_col3,#T_a7553_row22_col4,#T_a7553_row23_col3,#T_a7553_row23_col4,#T_a7553_row23_col28,#T_a7553_row24_col3,#T_a7553_row24_col4,#T_a7553_row24_col28,#T_a7553_row25_col3,#T_a7553_row25_col4,#T_a7553_row26_col3,#T_a7553_row26_col4,#T_a7553_row28_col3,#T_a7553_row28_col4,#T_a7553_row29_col3,#T_a7553_row29_col4,#T_a7553_row30_col4,#T_a7553_row31_col4,#T_a7553_row32_col4,#T_a7553_row32_col14{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col5,#T_a7553_row0_col8,#T_a7553_row9_col13,#T_a7553_row11_col8,#T_a7553_row20_col30,#T_a7553_row22_col17{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_a7553_row0_col6,#T_a7553_row1_col18,#T_a7553_row3_col13,#T_a7553_row4_col13,#T_a7553_row5_col15,#T_a7553_row7_col28,#T_a7553_row8_col15,#T_a7553_row12_col18,#T_a7553_row13_col7,#T_a7553_row14_col31,#T_a7553_row19_col11,#T_a7553_row21_col19,#T_a7553_row24_col13,#T_a7553_row25_col7,#T_a7553_row26_col7{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col7,#T_a7553_row1_col16,#T_a7553_row5_col19,#T_a7553_row8_col19,#T_a7553_row9_col16,#T_a7553_row9_col19,#T_a7553_row22_col19,#T_a7553_row23_col19,#T_a7553_row24_col14{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col9,#T_a7553_row1_col6,#T_a7553_row3_col6,#T_a7553_row4_col6,#T_a7553_row5_col11,#T_a7553_row5_col13,#T_a7553_row6_col19,#T_a7553_row12_col6,#T_a7553_row12_col11,#T_a7553_row16_col6,#T_a7553_row19_col7,#T_a7553_row19_col15,#T_a7553_row23_col1,#T_a7553_row23_col11,#T_a7553_row23_col13,#T_a7553_row24_col18,#T_a7553_row25_col13,#T_a7553_row26_col13,#T_a7553_row28_col6,#T_a7553_row29_col15,#T_a7553_row30_col15,#T_a7553_row31_col15,#T_a7553_row32_col15{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_a7553_row0_col10,#T_a7553_row6_col8,#T_a7553_row7_col23,#T_a7553_row16_col23,#T_a7553_row28_col5,#T_a7553_row29_col9,#T_a7553_row31_col10,#T_a7553_row32_col20{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_a7553_row0_col11,#T_a7553_row0_col28,#T_a7553_row1_col28,#T_a7553_row3_col28,#T_a7553_row4_col28,#T_a7553_row5_col28,#T_a7553_row6_col28,#T_a7553_row8_col28,#T_a7553_row12_col28,#T_a7553_row14_col1,#T_a7553_row14_col16,#T_a7553_row14_col28,#T_a7553_row16_col28,#T_a7553_row18_col28,#T_a7553_row19_col28,#T_a7553_row22_col28,#T_a7553_row25_col28,#T_a7553_row26_col28,#T_a7553_row29_col28,#T_a7553_row30_col3,#T_a7553_row30_col28,#T_a7553_row31_col28,#T_a7553_row32_col28{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col12,#T_a7553_row0_col17,#T_a7553_row1_col17,#T_a7553_row1_col20,#T_a7553_row2_col18,#T_a7553_row5_col7,#T_a7553_row6_col13,#T_a7553_row6_col25,#T_a7553_row6_col26,#T_a7553_row7_col25,#T_a7553_row7_col26,#T_a7553_row11_col18,#T_a7553_row16_col9,#T_a7553_row17_col29,#T_a7553_row19_col9,#T_a7553_row22_col13,#T_a7553_row25_col1,#T_a7553_row25_col11,#T_a7553_row26_col1,#T_a7553_row26_col11{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_a7553_row0_col13,#T_a7553_row0_col15,#T_a7553_row3_col7,#T_a7553_row4_col7,#T_a7553_row8_col7,#T_a7553_row11_col19,#T_a7553_row12_col7,#T_a7553_row16_col7,#T_a7553_row16_col11,#T_a7553_row22_col7,#T_a7553_row23_col16,#T_a7553_row24_col16,#T_a7553_row24_col19,#T_a7553_row25_col16,#T_a7553_row26_col16,#T_a7553_row29_col16{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col14,#T_a7553_row16_col5,#T_a7553_row16_col8,#T_a7553_row17_col30,#T_a7553_row19_col22{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_a7553_row0_col16,#T_a7553_row3_col1,#T_a7553_row3_col16,#T_a7553_row3_col19,#T_a7553_row4_col1,#T_a7553_row4_col16,#T_a7553_row4_col19,#T_a7553_row6_col1,#T_a7553_row6_col16,#T_a7553_row7_col1,#T_a7553_row7_col16,#T_a7553_row10_col32,#T_a7553_row11_col16,#T_a7553_row11_col28,#T_a7553_row12_col19,#T_a7553_row16_col19,#T_a7553_row18_col16,#T_a7553_row19_col1,#T_a7553_row19_col16,#T_a7553_row28_col1,#T_a7553_row28_col16,#T_a7553_row28_col19{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col18,#T_a7553_row3_col18,#T_a7553_row4_col18,#T_a7553_row14_col25,#T_a7553_row14_col26,#T_a7553_row14_col29,#T_a7553_row16_col18,#T_a7553_row20_col7,#T_a7553_row20_col18,#T_a7553_row24_col7,#T_a7553_row28_col18,#T_a7553_row30_col7{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col19,#T_a7553_row1_col19,#T_a7553_row14_col19,#T_a7553_row15_col16,#T_a7553_row17_col16,#T_a7553_row18_col1,#T_a7553_row20_col16,#T_a7553_row32_col19{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_a7553_row0_col20,#T_a7553_row15_col12,#T_a7553_row20_col6,#T_a7553_row20_col29{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_a7553_row0_col21,#T_a7553_row11_col14,#T_a7553_row22_col20,#T_a7553_row30_col9{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_a7553_row0_col22,#T_a7553_row6_col5,#T_a7553_row11_col5,#T_a7553_row15_col14{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_a7553_row0_col23,#T_a7553_row1

# %% [markdown]
# # Save Correlation Matrix to PNG

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cols = data.columns.shape[0]
imgsize = cols/2.5 # SET sIZING BASED ON COLUMNS AMOUNT
fig, ax = plt.subplots(sharex=True, figsize=(imgsize,imgsize))

# .2f is the precision of Correlation
sns.heatmap(data.corr(method='pearson'), annot=True, fmt='.2f', 
            cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax)

ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
plt.savefig(WorkSpaceName+'_Correlation_Matrix.png', bbox_inches='tight', pad_inches=0.0)

# %% [markdown]
# # How to get the Weight of Evidence (WOE) and Information Value
#
# https://stackoverflow.com/questions/60892714/how-to-get-the-weight-of-evidence-woe-and-information-value-iv-in-python-pan
#
#
#
# Credit risk models are mostly required to be interpretable and easy to understand. To achieve this all the independent variables will have to be categorical in nature. Since some variables are continuous we will employ the concept of Weight of Evidence.
#
# Weight of evidence will help us transform continuous variables into categorical features. The continuous variable is split into bins and based on their WOE , new variables are created. Also, information value helps us to determine which feature is useful in prediction. The information value for the independent variables are indicted below. Variables with IV less than 0.02 will not be included in the model because they have no prediction power Siddiqi(2006).

# %% [markdown]
# ![title](img/WOE.png)

# %% [markdown]
# As can be seen from the above figure, the correlation between variables is very small. The correlation coefficient between NumberOfOpenCreditLinesAndLoans and NumberRealEstateLoansOrLines is 0.43.
# Next, I further calculate the Infomation Value (IV) for each variable. IV index is generally used to determine the predictive ability of independent variables. The formula is:
# IV=sum((goodattribute-badattribute)*ln(goodattribute/badattribute))
# The criteria for judging the predictive ability of variables through IV value are:
# ##### < 0.02: unpredictive
# ##### 0.02 to 0.1: weak
# ##### 0.1 to 0.3: medium
# ##### 0.3 to 0.5: strong
# ##### > 0.5: suspicious

# %%
df = data

column = 'PrincipleAmount'
feature,target = column, 'Target'

print(data[column])
df_woe_iv = (pd.crosstab(df[feature],df[target],
                      normalize='columns')
             .assign(woe=lambda dfx: np.log(dfx[1] / dfx[0]))
             .assign(iv=lambda dfx: np.sum(dfx['woe']*
                                           (dfx[1]-dfx[0]))))

df_woe_iv
# Out:
# 0           20425.00
# 1            9556.00
# 2            2778.00
# 3               0.00
# 4           16876.00
#              ...
# 992076      25000.00
# 992077    1670535.00
# 992078       6989.09
# 992079      22274.13
# 992080      34159.51
# Name: PrincipleAmount, Length: 992081, dtype: float64
# C:\Users\t\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Target             0         1    2    3    4    5         6  woe   iv
# PrincipleAmount
# -11881.27        0.0  0.000002  0.0  0.0  0.0  0.0  0.000000  inf  inf
# -1054.00         0.0  0.000002  0.0  0.0  0.0  0.0  0.000000  inf  inf
# -503.99          0.0  0.000002  0.0  0.0  0.0  0.0  0.000000  inf  inf
# -298.01          0.0  0.000002  0.0  0.0  0.0  0.0  0.000000  inf  inf
# -260.00          0.0  0.000002  0.0  0.0  0.0  0.0  0.000000  inf  inf
# ...              ...       ...  ...  ...  ...  ...       ...  ...  ...
#  3653035.58      0.0  0.000000  0.0  0.0  0.0  0.0  0.003891  NaN  inf
#  3734824.41      0.0  0.000000  0.0  0.0  0.0  0.0  0.003891  NaN  inf
#  3895884.00      0.0  0.000000  0.0  0.0  0.0  0.0  0.003891  NaN  inf
#  4319790.31      0.0  0.000000  0.0  0.0  0.0  0.0  0.003891  NaN  inf
#  21095316.00     0.0  0.000000  0.0  0.0  0.0  0.0  0.003891  NaN  inf
#
# [501010 rows x 9 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier
np.set_printoptions(precision=5)

X = data[['term','loan_amnt','int_rate']]
Y = data[target] #Target
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
print(X.columns.values)
print(model.feature_importances_)

FeatureImportance = pd.DataFrame({'Feature':X.columns.values, 'Importance':model.feature_importances_})

print(FeatureImportance)

#Filter Most Important Feateure 0.3 Minimum
MOST_IMPORTANT = FeatureImportance[FeatureImportance['Importance'] > 0.1]
print('\nMOST_IMPORTANT Features')
print(MOST_IMPORTANT['Feature'].values)

NOT_IMPORTANT = FeatureImportance[FeatureImportance['Importance'] < 0.1]
print('\nNOT_IMPORTANT Features')
print(NOT_IMPORTANT['Feature'].values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-d10aa7ff4771> in <module>
#       2 np.set_printoptions(precision=5)
#       3
# ----> 4 X = data[['term','loan_amnt','int_rate']]
#       5 Y = data[target] #Target
#       6 model = ExtraTreesClassifier(n_estimators=10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['term', 'loan_amnt', 'int_rate'], dtype='object')] are in the [columns]"
